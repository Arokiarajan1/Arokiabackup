# %% [markdown]
# <a href="https://colab.research.google.com/github/Arokiarajan1/Arokiabackup/blob/main/Basic_Fundamental.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import polars as pl
from datetime import datetime
from scipy import misc
import matplotlib.pyplot as plt
from numpy import linalg
# %matplotlib inline
import nltk

# %%
df = pd.read_csv('Billionaires Statistics Dataset.csv')

# %%
df.set_index('rank').head(10).sort_values(by = "finalWorth", ascending=False)
# Out:
#       finalWorth               category                 personName   age  \
# rank
# 1         211000       Fashion & Retail   Bernard Arnault & family  74.0
# 2         180000             Automotive                  Elon Musk  51.0
# 3         114000             Technology                 Jeff Bezos  59.0
# 4         107000             Technology              Larry Ellison  78.0
# 5         106000  Finance & Investments             Warren Buffett  92.0
# 6         104000             Technology                 Bill Gates  67.0
# 7          94500  Media & Entertainment          Michael Bloomberg  81.0
# 8          93000                Telecom  Carlos Slim Helu & family  83.0
# 9          83400            Diversified              Mukesh Ambani  65.0
# 10         80700             Technology              Steve Ballmer  67.0
#
#             country         city              source             industries  \
# rank
# ...

# %%
df.style.background_gradient(cmap='coolwarm')

# %%
df.shape
# Out:
# (2640, 35)

# %%
len('df')
# Out:
# 2640

# %%
Pct_missing = df.isna().sum()/len(df)

# %%
Pct_missing = df.isna().sum()/len(df)
Pct_missing = Pct_missing.apply(lambda x: format(x, '.3%'))
Pct_missing = Pct_missing.sort_values(ascending=False)
print(Pct_missing)
# Out:
# organization                                  87.689%
# title                                         87.159%
# residenceStateRegion                          71.705%
# state                                         71.477%
# cpi_change_country                             6.970%
# cpi_country                                    6.970%
# tax_revenue_country_country                    6.932%
# total_tax_rate_country                         6.894%
# life_expectancy_country                        6.894%
# gross_tertiary_education_enrollment            6.894%
# gross_primary_education_enrollment_country     6.856%
# latitude_country                               6.212%
# population_country                             6.212%
# gdp_country                                    6.212%
# longitude_country                              6.212%
# birthDate                                      2.879%
# birthYear                                      2.879%
# ...

# %%
df.dtypes
# Out:
# rank                                            int64
# finalWorth                                      int64
# category                                       object
# personName                                     object
# age                                           float64
# country                                        object
# city                                           object
# source                                         object
# industries                                     object
# countryOfCitizenship                           object
# organization                                   object
# selfMade                                         bool
# status                                         object
# gender                                         object
# birthDate                                      object
# lastName                                       object
# firstName                                      object
# ...

# %%
df[['personName', 'age']].value_counts(ascending=False)
# Out:
# personName          age
# A. Jayson Adair     53.0    1
# Qinxiang Shao       68.0    1
# Pei Zhenhua         64.0    1
# Peng Zhao           52.0    1
# Penny Pritzker      63.0    1
#                            ..
# Huang Yi            61.0    1
# Hubert Burda        83.0    1
# Hui Ka Yan          64.0    1
# Hui Lin Chit        69.0    1
# Zygmunt Solorz-Zak  66.0    1
# Length: 2575, dtype: int64

# %%
df[['finalWorth','age']].describe()
# Out:
#           finalWorth          age
# count    2640.000000  2575.000000
# mean     4623.787879    65.140194
# std      9834.240939    13.258098
# min      1000.000000    18.000000
# 25%      1500.000000    56.000000
# 50%      2300.000000    65.000000
# 75%      4200.000000    75.000000
# max    211000.000000   101.000000

# %%
df[['finalWorth', 'age']].agg(['mean', 'sum', 'count', 'max', 'min','skew'])
# Out:
#          finalWorth            age
# mean   4.623788e+03      65.140194
# sum    1.220680e+07  167736.000000
# count  2.640000e+03    2575.000000
# max    2.110000e+05     101.000000
# min    1.000000e+03      18.000000
# skew   1.001237e+01      -0.078059

# %%
df.sort_values(by="finalWorth", ascending=False).head(5)
# Out:
#    rank  finalWorth               category                personName   age  \
# 0     1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1     2      180000             Automotive                 Elon Musk  51.0
# 2     3      114000             Technology                Jeff Bezos  59.0
# 3     4      107000             Technology             Larry Ellison  78.0
# 4     5      106000  Finance & Investments            Warren Buffett  92.0
#
#          country    city              source             industries  \
# 0         France   Paris                LVMH       Fashion & Retail
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
#
#   countryOfCitizenship  ...           gdp_country  \
# 0               France  ...   $2,715,518,274,227
# ...

# %%
## df['category'].str.lower() # lower string values
# df['category'].str.upper() # lower string values
#df['category'].str.split("& ") # lower string values
df['category'].str.len().median() # column string lenght
# Out:
# 13.0
